# %% [markdown]
# # BASIC LIBRARIES IMPORTING

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# # READ THE DATA FRAME

# %%
df = pd.read_csv(r"C:\Users\Pragya\Downloads\ML Question Paper\ML Question Paper\Datasets\credit_card.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %% [markdown]
# # Q1.Perform EDA on the given data. What does the primary analysis of several categorical features reveal? 🡪5 marks

# %% [markdown]
# **SHAPE OF DATA FRAME**

# %%
df.shape
# Out:
# (8950, 18)

# %% [markdown]
# **Columns**

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %% [markdown]
# **DESCRISPRITIVE STATISTICS OF DATA**

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# **Missing Values**

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# **SUMMARIZE INFO OF DATA**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %% [markdown]
# **DATA TYPE OF ALL VARIAVLE**

# %%
df.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %% [markdown]
# **ANAMOLY DETECTION**

# %%
for i in df.columns:
    print({i:df[i].unique()})
# Out:
# {'CUST_ID': array(['C10001', 'C10002', 'C10003', ..., 'C19188', 'C19189', 'C19190'],
#       dtype=object)}
# {'BALANCE': array([  40.900749, 3202.467416, 2495.148862, ...,   23.398673,
#          13.457564,  372.708075])}
# {'BALANCE_FREQUENCY': array([0.818182, 0.909091, 1.      , 0.636364, 0.545455, 0.875   ,
#        0.454545, 0.727273, 0.5     , 0.888889, 0.090909, 0.272727,
#        0.363636, 0.      , 0.666667, 0.75    , 0.857143, 0.181818,
#        0.333333, 0.6     , 0.3     , 0.125   , 0.9     , 0.833333,
#        0.8     , 0.2     , 0.777778, 0.555556, 0.25    , 0.142857,
#        0.571429, 0.4     , 0.444444, 0.714286, 0.222222, 0.1     ,
#        0.625   , 0.428571, 0.111111, 0.285714, 0.7     , 0.375   ,
#        0.166667])}
# {'PURCHASES': array([  95.4 ,    0.  ,  773.17, ...,  291.12,  144.4 , 1093.25])}
# {'ONEOFF_PURCHASES': array([   0.  ,  773.17, 1499.  , ...,  734.4 , 1012.73, 1093.25])}
# ...

# %% [markdown]
# **CHECKING FOR DUPLICATE ENTRIES**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # CONCLUSION:
# * Shape:
# --> There are 8950 rows and 17 columns are there in this dataset.
#
#
# * Descriptive Statistics:
#
# Numerical Summary:
#
# --> The average balance across customers is $1564.47, with a max balance of $19,043.
# --> Purchases vary widely, with an average of $1003.20, but some customers have purchases up to $49,039.
# --> Cash advances range from $0 to $47,137, with an average of $978.87.
# --> The average number of purchase transactions is 14.7, but some customers have up to 358 transactions.
#
# Categorical Insights:
#
# --> Tenure: Most customers have a tenure of 12 months.
#
# Full Payment Behavior:
# --> Majority of customers fall into the "Low" full payment category.
#
# Cash Advance Transactions:
# --> Most customers are in the "Low" category for cash advances, meaning they rarely take cash advances.
#
#
# * Missing Data:
#
# --> MINIMUM_PAYMENTS has 313 missing values.
# --> CREDIT_LIMIT has 1 missing value.
#
#
# * DataType:
# --> object = CUST_ID
# --> int  =  'PURCHASES_TRX', 'CREDIT_LIMIT', TENURE
# --> Float = 'CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_,'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT
#
#   'TRX'
# * Anomoly:
# --> No anomoly detected.
#
# * Duplicate:
# --> no duplicate entries are detected.

# %% [markdown]
# # Q2. Perform the following Exploratory Data Analysis tasks:🡪6 marks
# a. Missing Value Analysis
# b. Outlier Treatment using the Z-score method
# c. Deal with correlated variables

# %% [markdown]
# **HANDLING MISSING VALUE**

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
### missing value found in credit_limit fill it with mean
## missing value found in minimum payment fill it mean value.

mean_val= df['MINIMUM_PAYMENTS'].median()
df['MINIMUM_PAYMENTS'].fillna(value = mean_val, inplace=True)

mean_val= df['CREDIT_LIMIT'].median()
df['CREDIT_LIMIT'].fillna(value = mean_val, inplace=True)

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# **HANDLING OUTLIERS**

# %%
##Outlier Treatment using the Z-score method

# %%
df.drop(["CUST_ID"],axis=1,inplace=True)

# %%
for i in df.columns:
    df.boxplot(column=i)
    plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))  

# Create a boxplot for all numeric columns
df.boxplot()

# Customize plot appearance
plt.xticks(rotation=40, fontsize=12)  # Rotate and resize x-axis labels
plt.yticks(fontsize=12)               # Resize y-axis labels
plt.title('Boxplot of Numeric Columns', fontsize=16)  # Add title
plt.xlabel('Features', fontsize=14)   # Add x-axis label
plt.ylabel('Values', fontsize=14)     # Add y-axis label

# Show the plot
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %%
from scipy.stats import zscore 
df['zscore1'] = ( df.CASH_ADVANCE - df.CASH_ADVANCE.mean() ) / df.CASH_ADVANCE.std()
df.head()

df[df['zscore1']>3]

df[df['zscore1']<-3]

df_new = df[(df.zscore1>-3) & (df.zscore1<3)]

# %%
from scipy.stats import zscore 
df_new['zscore2'] = (df_new.PURCHASES - df_new.PURCHASES.mean() ) / df_new.PURCHASES.std()
df_new.head()

df_new[df_new['zscore2']>3]

df_new[df_new['zscore2']<-3]

df_new = df_new[(df_new.zscore2>-3) & (df_new.zscore2<3)]
df_new.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))  

# Create a boxplot for all numeric columns
df_new.boxplot()

# Customize plot appearance
plt.xticks(rotation=40, fontsize=12)  # Rotate and resize x-axis labels
plt.yticks(fontsize=12)               # Resize y-axis labels
plt.title('Boxplot of Numeric Columns', fontsize=16)  # Add title
plt.xlabel('Features', fontsize=14)   # Add x-axis label
plt.ylabel('Values', fontsize=14)     # Add y-axis label

# Show the plot
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %% [markdown]
# **HANDLING CORRELATD VARIABLES**

# %%
corr = df_new.corr()
corr
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.330235   0.113048
# BALANCE_FREQUENCY                 0.330235           1.000000   0.179192
# PURCHASES                         0.113048           0.179192   1.000000
# ONEOFF_PURCHASES                  0.113233           0.135718   0.862500
# INSTALLMENTS_PURCHASES            0.054510           0.149591   0.684287
# CASH_ADVANCE                      0.506549           0.108386  -0.130420
# PURCHASES_FREQUENCY              -0.091860           0.229482   0.547472
# ONEOFF_PURCHASES_FREQUENCY        0.057981           0.198327   0.619651
# PURCHASES_INSTALLMENTS_FREQUENCY -0.078306           0.174689   0.427354
# CASH_ADVANCE_FREQUENCY            0.434583           0.190031  -0.171325
# CASH_ADVANCE_TRX                  0.374002           0.144872  -0.114478
# PURCHASES_TRX                     0.105158           0.202031   0.730493
# ...

# %%
sns.heatmap(corr)
plt.show()

# %% [markdown]
# conclusion:
# --> when variavle are highly correlated then we need to handle it(>0.75)
# --> In this data set 2 set of variables are highly correlated(>0.8)
# so, we need to handle this.
# --> If 2 variable carring same information no need to keed both the variable
# so, i am deleting 2 variable out of 4 variable showing high correlation.

# %%
A = df[["PURCHASES_FREQUENCY","PURCHASES_INSTALLMENTS_FREQUENCY"]]

# %%
corr = A.corr()
corr
# Out:
#                                   PURCHASES_FREQUENCY  \
# PURCHASES_FREQUENCY                          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY             0.862934
#
#                                   PURCHASES_INSTALLMENTS_FREQUENCY
# PURCHASES_FREQUENCY                                       0.862934
# PURCHASES_INSTALLMENTS_FREQUENCY                          1.000000

# %%
B= df[["CASH_ADVANCE_FREQUENCY","CASH_ADVANCE_TRX"]]

# %%
corr = B.corr()
corr
# Out:
#                         CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX
# CASH_ADVANCE_FREQUENCY                1.000000          0.799561
# CASH_ADVANCE_TRX                      0.799561          1.000000

# %%
df.drop(["CASH_ADVANCE_FREQUENCY","PURCHASES_FREQUENCY"],axis = 1,inplace =True)

# %% [markdown]
# # Q3. Perform dimensionality reduction using PCA such that the 95% of the variance is explained🡪2 marks

# %%
new_df = df.copy(deep=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
new_df=scaler.fit_transform(new_df)

# %% [markdown]
# **pca with over all variables**

# %%
# Applying PCA
from sklearn.decomposition import PCA
pca = PCA(n_components = None) #to view the entire eigen vector,no subsetting
PrincipalComponents = pca.fit_transform(new_df)
explained_variance = pca.explained_variance_ratio_
print(explained_variance)
# Out:
# [2.68766163e-01 2.13584946e-01 8.74606222e-02 7.47602350e-02
#  6.18314579e-02 6.05848849e-02 4.97336176e-02 4.54384579e-02
#  3.75819413e-02 2.83431963e-02 2.45308821e-02 1.84299103e-02
#  1.51521834e-02 1.38007740e-02 7.28199089e-07 6.64207740e-33]

# %%
pca.n_components_
# Out:
# 11

# %% [markdown]
# **PCA with 95% of the variance**

# %%
# Applying PCA
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.95)
PrincipalComponents = pca.fit_transform(new_df)
explained_variance = pca.explained_variance_ratio_
print(explained_variance)
# Out:
# [0.26876616 0.21358495 0.08746062 0.07476023 0.06183146 0.06058488
#  0.04973362 0.04543846 0.03758194 0.0283432  0.02453088]

# %%
pca.n_components_
# Out:
# 11

# %% [markdown]
# conclusion:
#
# --> Out of 18 variable by passing 95% variance using pca i got 11 princical conponents.
# --> But we are not able to find which variable are considered as principal component.

# %% [markdown]
# # Q4. Find the optimum value of k for k-means clustering using the elbow method. Plot the elbow curve

# %% [markdown]
# **Creating X for model building**

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
X = df[[ 'BALANCE', 'BALANCE_FREQUENCY',
       'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES'
       , 'ONEOFF_PURCHASES_FREQUENCY',
       'PURCHASES_INSTALLMENTS_FREQUENCY',
       'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
       'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE']]

# %% [markdown]
# **Printing shape of X**

# %%
print(X.shape)
# Out:
# (8950, 13)

# %% [markdown]
# **Scaling X**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X=scaler.fit_transform(X)
print(X)
# Out:
# [[-0.73198937 -0.24943448 -0.35693402 ... -0.3024     -0.52555097
#    0.36067954]
#  [ 0.78696085  0.13432467 -0.35693402 ...  0.09749953  0.2342269
#    0.36067954]
#  [ 0.44713513  0.51808382  0.10888851 ... -0.0932934  -0.52555097
#    0.36067954]
#  ...
#  [-0.7403981  -0.18547673 -0.35693402 ... -0.32687479  0.32919999
#   -4.12276757]
#  [-0.74517423 -0.18547673 -0.35693402 ... -0.33830497  0.32919999
#   -4.12276757]
#  [-0.57257511 -0.88903307  0.30173158 ... -0.3243581  -0.52555097
#   -4.12276757]]

# %% [markdown]
# **Finding K value for model building**

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
 
wsse = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i,  random_state = 10)
    kmeans.fit(X)
    wsse.append(kmeans.inertia_)
plt.plot(range(1, 11), wsse)
plt.scatter(range(1, 11),wsse)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WSSE')
plt.show()

# %% [markdown]
# **Within-Cluster Sum of Squared Errors.**

# %%
print(wsse)
# Out:
# [116350.00000000007, 98573.8844153595, 89589.33668153317, 81386.44346422466, 74960.34768350424, 68044.22294541646, 62293.97212668127, 59599.67316537278, 56032.63137233397, 51763.28417459399]

# %% [markdown]
# Conclusion:
# ---> by observing the value of WSSE i finalise optimum value of k is 4.
# ---> because upto 4 WSSE value drop drastically and after k=4 values drop gradually

# %% [markdown]
# # Q5. Find the optimum value of k for k-means clustering using the silhouette score method.
# # Build a K-means clustering model and specify the number of observations in each cluster using a bar plot🡪5 marks

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# create a list for different values of K
n_clusters = [2,3,4, 5, 6,7, 8, 9,10]

# use 'for' loop to build the clusters
# 'random_state' returns the same sample each time you run the code  
# fit and predict on the scaled data
# 'silhouette_score' function computes the silhouette score for each K
for K in n_clusters :
    cluster = KMeans(n_clusters= K, random_state= 10)
    predict = cluster.fit_predict(X)
    
    score = silhouette_score(X, predict, random_state= 10)
    print ("For n_clusters = {}, silhouette score is {})".format(K, score))
# Out:
# For n_clusters = 2, silhouette score is 0.3474427458795797)
# For n_clusters = 3, silhouette score is 0.17333191893221958)
# For n_clusters = 4, silhouette score is 0.18873483310299524)
# For n_clusters = 5, silhouette score is 0.21078198594687972)
# For n_clusters = 6, silhouette score is 0.21153295995826754)
# For n_clusters = 7, silhouette score is 0.22381964921744468)
# For n_clusters = 8, silhouette score is 0.22646583066979187)
# For n_clusters = 9, silhouette score is 0.23192743722392897)
# For n_clusters = 10, silhouette score is 0.23556047159556837)

# %%
# fitting k-mean to the dataset
model = KMeans(n_clusters = 2,  random_state = 10)

# %%
# fit the model
model.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=10)

# %%
Y_pred = kmeans.fit_predict(X)
Y_pred
# Out:
# array([8, 8, 5, ..., 2, 2, 2])

# %%
kmeans.inertia_
# Out:
# 65392.21547322496

# %%
kmeans.n_iter_
# Out:
# 25

# %%
df["Clusters"] = Y_pred
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  ONEOFF_PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000                    0.000000
# 1                     0.0   6442.945483                    0.000000
# 2                     0.0      0.000000                    1.000000
# 3                     0.0    205.788017                    0.083333
# 4                     0.0      0.000000                    0.083333
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# 0                          0.083333                 0              2
# ...

# %%
print(wsse)
# Out:
# [152150.00000000017, 130662.1560043649, 116839.1058539576, 108092.59578037627, 99667.03998503048, 93498.8364392487, 87594.82519564866, 75608.73494235401, 69990.49284847715, 65392.21547322496]

# %%
df_output = df.copy(deep = True)
# add a column 'Cluster' in the data giving cluster number corresponding to each observation
df_output['Cluster'] = model.labels_

# head() to display top five rows
df_output.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  ONEOFF_PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000                    0.000000
# 1                     0.0   6442.945483                    0.000000
# 2                     0.0      0.000000                    1.000000
# 3                     0.0    205.788017                    0.083333
# 4                     0.0      0.000000                    0.083333
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# 0                          0.083333                 0              2
# ...

# %%
# 'return_counts = True' gives the number observation in each cluster
np.unique(model.labels_, return_counts=True)
# Out:
# (array([0, 1]), array([7516, 1434], dtype=int64))

# %%
# 'return_counts = True' gives the number observation in each cluster
np.unique(model.labels_, return_counts=True)


# use 'seaborn' library to plot a barplot for cluster size
sns.countplot(data= df_output, x = 'Cluster')

# set the axes and plot labels
# set the font size using 'fontsize'
plt.title('Cluster Sizes', fontsize = 15)
plt.xlabel('Clusters', fontsize = 15)
plt.ylabel('No. of Customers', fontsize = 15)

# add values in the graph
# 'x' and 'y' assigns the position to the text
# 's' represents the text on the plot
plt.text(x = -0.18, y =2000, s = np.unique(model.labels_, return_counts=True)[1][0])
plt.text(x = 0.9, y =2000, s = np.unique(model.labels_, return_counts=True)[1][1])

plt.show()

# %% [markdown]
# ### 2 Clusters are obtained having 6930 and 1706 no of observations.
